# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimazain118/ML/blob/main/7_Bivariate_lmplots_of_Boston_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive              
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("/content/gdrive/MyDrive/Boston.csv")

# %%
data.head(n=5)
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
data=data.drop( 'Unnamed: 0', axis = 1)

# %%
data.shape
# Out:
# (506, 14)

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# ## Bivariate lmplots:

# %%
import seaborn as sns

# %%
data.corr()
# Out:
#              crim        zn     indus  ...     black     lstat      medv
# crim     1.000000 -0.200469  0.406583  ... -0.385064  0.455621 -0.388305
# zn      -0.200469  1.000000 -0.533828  ...  0.175520 -0.412995  0.360445
# indus    0.406583 -0.533828  1.000000  ... -0.356977  0.603800 -0.483725
# chas    -0.055892 -0.042697  0.062938  ...  0.048788 -0.053929  0.175260
# nox      0.420972 -0.516604  0.763651  ... -0.380051  0.590879 -0.427321
# rm      -0.219247  0.311991 -0.391676  ...  0.128069 -0.613808  0.695360
# age      0.352734 -0.569537  0.644779  ... -0.273534  0.602339 -0.376955
# dis     -0.379670  0.664408 -0.708027  ...  0.291512 -0.496996  0.249929
# rad      0.625505 -0.311948  0.595129  ... -0.444413  0.488676 -0.381626
# tax      0.582764 -0.314563  0.720760  ... -0.441808  0.543993 -0.468536
# ptratio  0.289946 -0.391679  0.383248  ... -0.177383  0.374044 -0.507787
# black   -0.385064  0.175520 -0.356977  ...  1.000000 -0.366087  0.333461
# ...

# %% [markdown]
# - (-)ve sign represents "Negative Correlation".
# - (+)ve values represents "Positive Correlation".

# %%
sns.lmplot(x='crim',y='zn', data=data)

# %% [markdown]
# Result:"Negative Correlation".

# %%
sns.lmplot(x='crim',y='indus', data=data)

# %% [markdown]
# Result: "Positive Correlation".

# %%
sns.lmplot(x='crim',y='chas', data=data)

# %% [markdown]
# Result: "Negative Correlation".

# %%
sns.lmplot(x='crim',y='nox', data=data)

# %% [markdown]
# Result: "Positive Correlation".

# %%
sns.lmplot(x='crim',y='rm', data=data)

# %% [markdown]
# Result: "Negative Correlation".

# %%
sns.lmplot(x='crim',y='dis', data=data)

# %% [markdown]
# Result: "Negative Correlation".

# %%
sns.lmplot(x='crim',y='rad', data=data)

# %% [markdown]
# Result: "Positive Correlation".

# %%
sns.lmplot(x='crim',y='tax', data=data)

# %% [markdown]
# Result: "Positive Correlation".

# %%
sns.lmplot(x='crim',y='ptratio', data=data)

# %% [markdown]
# Result: "Positive Correlation".

# %%
sns.lmplot(x='crim',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='crim',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='crim',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='indus', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='chas', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='nox', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='rm', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='zn',y='age', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='dis', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='zn',y='rad', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='tax', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='ptratio', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='black', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='zn',y='lstat', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='zn',y='medv', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='chas', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='nox', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='rm', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='indus',y='age', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='dis', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='indus',y='rad', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='tax', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='ptratio', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='indus',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='indus',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='chas',y='rm', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='chas',y='age', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='chas',y='dis', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='chas',y='rad', data=data)

# %% [markdown]
# Result: No Correlation

# %%
sns.lmplot(x='chas',y='tax', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='chas',y='ptratio', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='chas',y='black', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='chas',y='lstat', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='chas',y='medv', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='rm', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='nox',y='age', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='dis', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='nox',y='rad', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='tax', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='ptratio', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='nox',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='nox',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='age', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='dis', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rm',y='rad', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='tax', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='ptratio', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='black', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rm',y='lstat', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rm',y='medv', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='age',y='dis', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='age',y='rad', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='age',y='ptratio', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='age',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='age',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='age',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='dis',y='rad', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='dis',y='tax', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='dis',y='ptratio', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='dis',y='black', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='dis',y='lstat', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='dis',y='medv', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rad',y='tax', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rad',y='ptratio', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rad',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='rad',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='rad',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='tax',y='ptratio', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='tax',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='tax',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='tax',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='ptratio',y='black', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='ptratio',y='lstat', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='ptratio',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='black',y='lstat', data=data)

# %% [markdown]
# Result: Negative Correlation

# %%
sns.lmplot(x='black',y='medv', data=data)

# %% [markdown]
# Result: Positive Correlation

# %%
sns.lmplot(x='lstat',y='medv', data=data)

# %% [markdown]
# Result: Negative Correlation
